# %% [markdown]
# # Welcome to Colab!
#
# ## Explore the Gemini API
# The Gemini API gives you access to Gemini models created by Google DeepMind. Gemini models are built from the ground up to be multimodal, so you can reason seamlessly across text, images, code, and audio.
#
# **How to get started?**
# *  Go to [Google AI Studio](https://aistudio.google.com/) and log in with your Google account.
# *  [Create an API key](https://aistudio.google.com/app/apikey).
# * Use a quickstart for [Python](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Get_started.ipynb), or call the REST API using [curl](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/rest/Prompting_REST.ipynb).
#
# **Discover Gemini's advanced capabilities**
# *  Play with Gemini [multimodal outputs](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Image-out.ipynb), mixing text and images in an iterative way.
# *  Discover the [multimodal Live API](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Get_started_LiveAPI.ipynb ) (demo [here](https://aistudio.google.com/live)).
# *  Learn how to [analyze images and detect items in your pictures](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Spatial_understanding.ipynb") using Gemini (bonus, there's a [3D version](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Spatial_understanding_3d.ipynb) as well!).
# *  Unlock the power of [Gemini thinking model](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Get_started_thinking.ipynb), capable of solving complex task with its inner thoughts.
#
# **Explore complex use cases**
# *  Use [Gemini grounding capabilities](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Search_grounding_for_research_report.ipynb) to create a report on a company based on what the model can find on internet.
# *  Extract [invoices and form data from PDF](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Pdf_structured_outputs_on_invoices_and_forms.ipynb) in a structured way.
# *  Create [illustrations based on a whole book](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Book_illustration.ipynb) using Gemini large context window and Imagen.
#
# To learn more, check out the [Gemini cookbook](https://github.com/google-gemini/cookbook) or visit the [Gemini API documentation](https://ai.google.dev/docs/).

# %% [markdown]
# Colab now has AI features powered by [Gemini](https://gemini.google.com). The video below provides information on how to use these features, whether you're new to Python, or a seasoned veteran.
#
# <center>
#   <a href="https://www.youtube.com/watch?v=V7RXyqFUR98" target="_blank">
#   <img alt='Thumbnail for a video showing 3 AI-powered Google Colab features' src="data:image/png;base64,..." height="188" width="336">
#   </a>
# </center>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h2>What is Colab?</h2>
# </div>
#
# Colab, or "Colaboratory", allows you to write and execute Python in your browser, with
# - Zero configuration required
# - Access to GPUs free of charge
# - Easy sharing
#
# Whether you're a **student**, a **data scientist** or an **AI researcher**, Colab can make your work easier. Watch [Introduction to Colab](https://www.youtube.com/watch?v=inN8seMm7UI) or [Colab Features You May Have Missed](https://www.youtube.com/watch?v=rNgswRZ2C1Y) to learn more, or just get started below!

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## **Getting started**
# </div>
#
# The document you are reading is not a static web page, but an interactive environment called a **Colab notebook** that lets you write and execute code.
#
# For example, here is a **code cell** with a short Python script that computes a value, stores it in a variable, and prints the result:

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# To execute the code in the above cell, select it with a click and then either press the play button to the left of the code, or use the keyboard shortcut "Command/Ctrl+Enter". To edit the code, just click the cell and start editing.
#
# Variables that you define in one cell can later be used in other cells:

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# Colab notebooks allow you to combine **executable code** and **rich text** in a single document, along with **images**, **HTML**, **LaTeX** and more. When you create your own Colab notebooks, they are stored in your Google Drive account. You can easily share your Colab notebooks with co-workers or friends, allowing them to comment on your notebooks or even edit them. To learn more, see [Overview of Colab](/notebooks/basic_features_overview.ipynb). To create a new Colab notebook you can use the File menu above, or use the following link: [create a new Colab notebook](http://colab.research.google.com#create=true).
#
# Colab notebooks are Jupyter notebooks that are hosted by Colab. To learn more about the Jupyter project, see [jupyter.org](https://www.jupyter.org).

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Data science
# </div>
#
# With Colab you can harness the full power of popular Python libraries to analyze and visualize data. The code cell below uses **numpy** to generate some random data, and uses **matplotlib** to visualize it. To edit the code, just click the cell and start editing.

# %% [markdown]
# You can import your own data into Colab notebooks from your Google Drive account, including from spreadsheets, as well as from Github and many other sources. To learn more about importing data, and how Colab can be used for data science, see the links below under [Working with Data](#working-with-data).

# %%
import numpy as np
import IPython.display as display
from matplotlib import pyplot as plt
import io
import base64

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

fig = plt.figure(figsize=(4, 3), facecolor='w')
plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)
plt.title("Sample Visualization", fontsize=10)

data = io.BytesIO()
plt.savefig(data)
image = F"data:image/png;base64,{base64.b64encode(data.getvalue()).decode()}"
alt = "Sample Visualization"
display.display(display.Markdown(F"""![{alt}]({image})"""))
plt.close(fig)
# Out:
# ![Sample Visualization](data:image/png;base64,...)

# %% [markdown]
# Colab notebooks execute code on Google's cloud servers, meaning you can leverage the power of Google hardware, including [GPUs and TPUs](#using-accelerated-hardware), regardless of the power of your machine. All you need is a browser.
#
# For example, if you find yourself waiting for **pandas** code to finish running and want to go faster, you can switch to a GPU Runtime and use libraries like [RAPIDS cuDF](https://rapids.ai/cudf-pandas) that provide zero-code-change acceleration.

# %% [markdown]
# To learn more about accelerating pandas on Colab, see the [10 minute guide](https://colab.research.google.com/github/rapidsai-community/showcase/blob/main/getting_started_tutorials/cudf_pandas_colab_demo.ipynb) or
#  [US stock market data analysis demo](https://colab.research.google.com/github/rapidsai-community/showcase/blob/main/getting_started_tutorials/cudf_pandas_stocks_demo.ipynb).

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Machine learning
# </div>
#
# With Colab you can import an image dataset, train an image classifier on it, and evaluate the model, all in just [a few lines of code](https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb).

# %% [markdown]
# Colab is used extensively in the machine learning community with applications including:
# - Getting started with TensorFlow
# - Developing and training neural networks
# - Experimenting with TPUs
# - Disseminating AI research
# - Creating tutorials
#
# To see sample Colab notebooks that demonstrate machine learning applications, see the [machine learning examples](#machine-learning-examples) below.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## More Resources
#
# ### Working with Notebooks in Colab
#
# </div>
#
# - [Overview of Colab](/notebooks/basic_features_overview.ipynb)
# - [Guide to Markdown](/notebooks/markdown_guide.ipynb)
# - [Importing libraries and installing dependencies](/notebooks/snippets/importing_libraries.ipynb)
# - [Saving and loading notebooks in GitHub](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/colab-github-demo.ipynb)
# - [Interactive forms](/notebooks/forms.ipynb)
# - [Interactive widgets](/notebooks/widgets.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="working-with-data"></a>
# ### Working with Data
# </div>
#
# - [Loading data: Drive, Sheets, and Google Cloud Storage](/notebooks/io.ipynb)
# - [Charts: visualizing data](/notebooks/charts.ipynb)
# - [Getting started with BigQuery](/notebooks/bigquery.ipynb)
#
# <div class="markdown-google-sans">
#
# ### Machine Learning Crash Course
#
# <div>
#
# These are a few of the notebooks from Google's online Machine Learning course. See the [full course website](https://developers.google.com/machine-learning/crash-course/) for more.
# - [Intro to Pandas DataFrame](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb)
# - [Intro to RAPIDS cuDF to accelerate pandas](https://nvda.ws/rapids-cudf)
# - [Linear regression with tf.keras using synthetic data](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/linear_regression_with_synthetic_data.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="using-accelerated-hardware"></a>
# ### Using Accelerated Hardware
# </div>
#
# - [TensorFlow with GPUs](/notebooks/gpu.ipynb)
# - [TPUs in Colab](/notebooks/tpu.ipynb)

# %% [markdown]
# <div class="markdown-google-sans">
#
# <a name="machine-learning-examples"></a>
#
# ### Featured examples
#
# </div>
#
# - [Retraining an Image Classifier](https://tensorflow.org/hub/tutorials/tf2_image_retraining): Build a Keras model on top of a pre-trained image classifier to distinguish flowers.
# - [Text Classification](https://tensorflow.org/hub/tutorials/tf2_text_classification): Classify IMDB movie reviews as either *positive* or *negative*.
# - [Style Transfer](https://tensorflow.org/hub/tutorials/tf2_arbitrary_image_stylization): Use deep learning to transfer style between images.
# - [Multilingual Universal Sentence Encoder Q&A](https://tensorflow.org/hub/tutorials/retrieval_with_tf_hub_universal_encoder_qa): Use a machine learning model to answer questions from the SQuAD dataset.
# - [Video Interpolation](https://tensorflow.org/hub/tutorials/tweening_conv3d): Predict what happened in a video between the first and the last frame.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
df=pd.read_csv('/content/fake_medical_data_with_issues.csv')

# %%
df.head()
# Out:
#   Patient_ID    Age Gender  Height_cm  Weight_kg    BMI Blood_Pressure  \
# 0      P1000   25.0   Male      160.0       70.0  100.0            NaN
# 1      P1001   40.0   Male      175.0       80.0   22.0            NaN
# 2      P1002  102.0    NaN        NaN      -45.0   27.5            NaN
# 3      P1003  150.0    NaN      180.0       80.0  100.0         120/80
# 4      P1004   40.0    NaN      999.0       90.0  100.0        200/150
#
#    Heart_Rate Cholesterol Diabetes Smoker Exercise_Freq Alcohol_Intake  \
# 0        72.0      Normal        Y    NaN        Weekly            NaN
# 1       -20.0        High        Y     No         Never           High
# 2       -20.0      Normal        Y    NaN         Daily            NaN
# 3       100.0         NaN      NaN     No        Weekly            NaN
# 4         NaN         NaN       No    NaN        Weekly           High
#
#   Medication Diagnosis  Visit_Date  Follow_Up_Days        Doctor_Notes  \
# 0      DrugB       NaN  not_a_date             NaN                 NaN
# 1        NaN  Diabetes  not_a_date            60.0            Check BP
# 2      DrugB  Diabetes  2025-01-10             NaN                 NaN
# 3      DrugA       NaN         NaN            30.0                 NaN
# 4        NaN       NaN  2025-01-10            90.0  Follow-up required
#
#   Insurance_Status    Hospital
# 0        Uninsured         NaN
# 1              NaN         NaN
# 2              NaN         NaN
# 3          Insured  Hospital B
# 4              NaN         NaN

# %%
data=df.copy()

# %%
df.shape
# Out:
# (200, 20)

# %%
df.isnull().sum()
# Out:
# Patient_ID            0
# Age                  27
# Gender               75
# Height_cm            37
# Weight_kg            31
# BMI                  44
# Blood_Pressure       45
# Heart_Rate           37
# Cholesterol          73
# Diabetes             40
# Smoker              124
# Exercise_Freq         0
# Alcohol_Intake      120
# Medication           81
# Diagnosis           114
# Visit_Date           63
# Follow_Up_Days       48
# Doctor_Notes         98
# Insurance_Status    105
# Hospital            100
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Patient_ID        200 non-null    object
#  1   Age               173 non-null    float64
#  2   Gender            125 non-null    object
#  3   Height_cm         163 non-null    float64
#  4   Weight_kg         169 non-null    float64
#  5   BMI               156 non-null    float64
#  6   Blood_Pressure    155 non-null    object
#  7   Heart_Rate        163 non-null    float64
#  8   Cholesterol       127 non-null    object
#  9   Diabetes          160 non-null    object
#  10  Smoker            76 non-null     object
#  11  Exercise_Freq     200 non-null    object
#  12  Alcohol_Intake    80 non-null     object
#  13  Medication        119 non-null    object
#  14  Diagnosis         86 non-null     object
#  15  Visit_Date        137 non-null    object
#  16  Follow_Up_Days    152 non-null    float64
#  17  Doctor_Notes      102 non-null    object
#  18  Insurance_Status  95 non-null     object
#  19  Hospital          100 non-null    object
# dtypes: float64(6), object(14)
# memory usage: 31.4+ KB

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)  #fill missing value
# Out:
# <ipython-input-8-725f7de4c048>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(),inplace=True)  #fill missing value

# %%
df['Age'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Gender'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 200 entries, 0 to 199
# Series name: Gender
# Non-Null Count  Dtype
# --------------  -----
# 125 non-null    object
# dtypes: object(1)
# memory usage: 1.7+ KB

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male       45
# Female     40
# Unknown    40
# Name: count, dtype: int64

# %%
null_indices = df[df['Gender'].isna()].index
fill_values = ['Female'] * 65 + ['Male'] * 10
np.random.shuffle(fill_values)
df.loc[null_indices, 'Gender'] = fill_values

# %%
df['Gender'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 200 entries, 0 to 199
# Series name: Gender
# Non-Null Count  Dtype
# --------------  -----
# 200 non-null    object
# dtypes: object(1)
# memory usage: 1.7+ KB

# %%
df['Height_cm'].fillna(df['Height_cm'].mean(),inplace=True)
df['Weight_kg'].fillna(df['Weight_kg'].mean(),inplace=True)    # replace missing values
# Out:
# <ipython-input-14-3e514bf48f98>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Height_cm'].fillna(df['Height_cm'].mean(),inplace=True)
# <ipython-input-14-3e514bf48f98>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Weight_kg'].fillna(df['Weight_kg'].mean(),inplace=True)    # replace missing values

# %%
df['Height_cm'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Weight_kg'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['BMI'].value_counts()
# Out:
# BMI
# -3.0      42
#  27.5     41
#  100.0    37
#  22.0     36
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='BMI', data=df, palette='Set2')
plt.title('BMI Category Distribution')
plt.xlabel('BMI Category')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-18-1157035f41aa>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='BMI', data=df, palette='Set2')

# %%
df['BMI'].fillna(df['BMI'].mode()[0], inplace=True)
# Out:
# <ipython-input-19-0123e657a9df>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['BMI'].fillna(df['BMI'].mode()[0], inplace=True)

# %%
df['BMI'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Blood_Pressure'].value_counts()
# Out:
# Blood_Pressure
# 200/150    48
# 120/80     38
# 140/90     37
# invalid    32
# Name: count, dtype: int64

# %%
if 'Blood_Pressure' in df.columns:
    split_cols = df['Blood_Pressure'].str.split('/', expand=True)
    df['Systolic'] = pd.to_numeric(split_cols[0], errors='coerce')
    df['Diastolic'] = pd.to_numeric(split_cols[1], errors='coerce')

# %%
df.drop('Patient_ID',axis=1,inplace=True)
df.drop('Blood_Pressure',axis=1,inplace=True)

# %%
df['Heart_Rate'].isnull().sum()
# Out:
# np.int64(37)

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='Heart_Rate', data=df, palette='Set2')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-25-2a11d2e72dce>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Heart_Rate', data=df, palette='Set2')

# %%
df['Heart_Rate'].fillna(df['BMI'].mode()[0], inplace=True)
# Out:
# <ipython-input-26-c10694b8a505>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Heart_Rate'].fillna(df['BMI'].mode()[0], inplace=True)

# %%
df['Heart_Rate'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Cholesterol'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 200 entries, 0 to 199
# Series name: Cholesterol
# Non-Null Count  Dtype
# --------------  -----
# 127 non-null    object
# dtypes: object(1)
# memory usage: 1.7+ KB

# %%
null_indices = df[df['Cholesterol'].isna()].index
n_nulls = len(null_indices)
fill_values = ['Normal'] * 40 + ['High'] * 45 + ['Low'] * 42
total_known = len(fill_values)
p_normal = 40 / total_known
p_high = 45 / total_known
p_low = 42 / total_known
n_normal = int(p_normal * n_nulls)
n_high = int(p_high * n_nulls)
n_low = n_nulls - n_normal - n_high
fill_nulls = ['normal'] * n_normal + ['high'] * n_high + ['low'] * n_low
np.random.shuffle(fill_nulls)
df.loc[null_indices, 'Cholesterol'] = fill_nulls

# %%
df['Diabetes'].value_counts()
# Out:
# Diabetes
# Y          45
# No         43
# Unknown    42
# Yes        30
# Name: count, dtype: int64

# %%
null_indices = df[df['Diabetes'].isna()].index
count_y = 45
count_no = 43
count_yes = 30
total_known = count_y + count_no + count_yes
p_y = count_y / total_known
p_no = count_no / total_known
p_yes = count_yes / total_known
n_nulls = len(null_indices)
n_y = int(p_y * n_nulls)
n_no = int(p_no * n_nulls)
n_yes = n_nulls - n_y - n_no
fill_values = ['Y'] * n_y + ['No'] * n_no + ['Yes'] * n_yes
np.random.shuffle(fill_values)
df.loc[null_indices, 'Diabetes'] = fill_values

# %%
df['Diabetes'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 200 entries, 0 to 199
# Series name: Diabetes
# Non-Null Count  Dtype
# --------------  -----
# 200 non-null    object
# dtypes: object(1)
# memory usage: 1.7+ KB

# %%
df['Smoker'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 200 entries, 0 to 199
# Series name: Smoker
# Non-Null Count  Dtype
# --------------  -----
# 76 non-null     object
# dtypes: object(1)
# memory usage: 1.7+ KB

# %%
df.drop('Smoker',axis=1,inplace=True)

# %%
df['Exercise_Freq'].value_counts()
# Out:
# Exercise_Freq
# Daily      49
# invalid    41
# Never      40
# Rarely     36
# Weekly     34
# Name: count, dtype: int64

# %%
null_indices = df[df['Exercise_Freq'].isna()].index
count_daily = 49
count_never = 40
count_rarely = 36
count_weekly = 34
total_known = count_daily + count_never + count_rarely + count_weekly
p_daily = count_daily / total_known
p_never = count_never / total_known
p_rarely = count_rarely / total_known
p_weekly = count_weekly / total_known
n_nulls = len(null_indices)
n_daily = int(p_daily * n_nulls)
n_never = int(p_never * n_nulls)
n_rarely = int(p_rarely * n_nulls)
n_weekly = n_nulls - n_daily - n_never - n_rarely
fill_values = (
    ['Daily'] * n_daily +
    ['Never'] * n_never +
    ['Rarely'] * n_rarely +
    ['Weekly'] * n_weekly
)
np.random.shuffle(fill_values)
df.loc[null_indices, 'Exercise_Freq'] = fill_values

# %%
df['Exercise_Freq'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 200 entries, 0 to 199
# Series name: Exercise_Freq
# Non-Null Count  Dtype
# --------------  -----
# 200 non-null    object
# dtypes: object(1)
# memory usage: 1.7+ KB

# %%
df['Medication'].value_counts()
# Out:
# Medication
# DrugA      45
# DrugB      39
# Unknown    35
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='Medication', data=df, palette='Set2')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-40-14daf556579b>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Medication', data=df, palette='Set2')

# %%
df['Medication'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 200 entries, 0 to 199
# Series name: Medication
# Non-Null Count  Dtype
# --------------  -----
# 119 non-null    object
# dtypes: object(1)
# memory usage: 1.7+ KB

# %%
null_indices = df[df['Medication'].isna()].index
count_druga = 45
count_drugb = 39
count_unknown = 35
total_known = count_druga + count_drugb + count_unknown
p_druga = count_druga / total_known
p_drugb = count_drugb / total_known
p_unknown = count_unknown / total_known
n_nulls = len(null_indices)
n_druga = int(p_druga * n_nulls)
n_drugb = int(p_drugb * n_nulls)
n_unknown = n_nulls - n_druga - n_drugb
fill_values = (
    ['DrugA'] * n_druga +
    ['DrugB'] * n_drugb +
    ['Unknown'] * n_unknown
)
np.random.shuffle(fill_values)
df.loc[null_indices, 'Medication'] = fill_values

# %%
df['Medication'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 200 entries, 0 to 199
# Series name: Medication
# Non-Null Count  Dtype
# --------------  -----
# 200 non-null    object
# dtypes: object(1)
# memory usage: 1.7+ KB

# %%
df['Diagnosis'].value_counts()
# Out:
# Diagnosis
# Diabetes        48
# Hypertension    38
# Name: count, dtype: int64

# %%
df['Diagnosis'].isnull().sum()
# Out:
# np.int64(114)

# %%
null_indices = df[df['Diagnosis'].isna()].index
count_diabetes = 48
count_hypertension = 38
total_known = count_diabetes + count_hypertension
p_diabetes = count_diabetes / total_known
p_hypertension = count_hypertension / total_known
n_nulls = len(null_indices)
n_diabetes = int(p_diabetes * n_nulls)
n_hypertension = n_nulls - n_diabetes
fill_values = (
    ['Diabetes'] * n_diabetes +
    ['Hypertension'] * n_hypertension
)
np.random.shuffle(fill_values)
df.loc[null_indices, 'Diagnosis'] = fill_values

# %%
df['Diagnosis'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 200 entries, 0 to 199
# Series name: Diagnosis
# Non-Null Count  Dtype
# --------------  -----
# 200 non-null    object
# dtypes: object(1)
# memory usage: 1.7+ KB

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='Diagnosis', data=df, palette='Set2')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-49-5faf6af03390>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Diagnosis', data=df, palette='Set2')

# %%
df['Visit_Date'].value_counts()
# Out:
# Visit_Date
# not_a_date    47
# 2025-01-10    47
# 2025-02-20    43
# Name: count, dtype: int64

# %%
df['Visit_Date'] = pd.to_datetime(df['Visit_Date'], errors='coerce')
null_indices = df[df['Visit_Date'].isna()].index
n_nulls = len(null_indices)
date1 = pd.Timestamp('2025-01-10')
date2 = pd.Timestamp('2025-02-20')
count_date1 = 47
count_date2 = 43
total_known = count_date1 + count_date2
p_date1 = count_date1 / total_known
p_date2 = count_date2 / total_known
n_date1 = int(p_date1 * n_nulls)
n_date2 = n_nulls - n_date1
fill_values = [date1] * n_date1 + [date2] * n_date2
np.random.shuffle(fill_values)
df.loc[null_indices, 'Visit_Date'] = fill_values
# Out:
# <ipython-input-51-b51230d6794a>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Visit_Date'] = pd.to_datetime(df['Visit_Date'], errors='coerce')

# %%
df['Year'] = df['Visit_Date'].dt.year
df['Month'] = df['Visit_Date'].dt.month
df['Day'] = df['Visit_Date'].dt.day
df['Weekday'] = df['Visit_Date'].dt.weekday

# %%
df['Visit_Date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 200 entries, 0 to 199
# Series name: Visit_Date
# Non-Null Count  Dtype
# --------------  -----
# 200 non-null    datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 1.7 KB

# %%
df['Follow_Up_Days'].value_counts()
# Out:
# Follow_Up_Days
#  60.0    40
#  30.0    39
# -10.0    39
#  90.0    34
# Name: count, dtype: int64

# %%
df['Follow_Up_Days'].isnull().sum()
# Out:
# np.int64(48)

# %%
df['Follow_Up_Days'].fillna(df['Follow_Up_Days'].mean(), inplace=True)
# Out:
# <ipython-input-57-3c87e6468c3d>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Follow_Up_Days'].fillna(df['Follow_Up_Days'].mean(), inplace=True)

# %%
df['Follow_Up_Days'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#      Age  Gender   Height_cm  Weight_kg    BMI  Heart_Rate Cholesterol  \
# 0   25.0    Male  160.000000       70.0  100.0        72.0      Normal
# 1   40.0    Male  175.000000       80.0   22.0       -20.0        High
# 2  102.0  Female  244.141104      -45.0   27.5       -20.0      Normal
# 3  150.0  Female  180.000000       80.0  100.0       100.0      normal
# 4   40.0    Male  999.000000       90.0  100.0        -3.0      normal
#
#   Diabetes Exercise_Freq Alcohol_Intake  ... Follow_Up_Days  \
# 0        Y        Weekly            NaN  ...      41.052632
# 1        Y         Never           High  ...      60.000000
# 2        Y         Daily            NaN  ...      41.052632
# 3       No        Weekly            NaN  ...      30.000000
# 4       No        Weekly           High  ...      90.000000
#
#          Doctor_Notes Insurance_Status    Hospital Systolic Diastolic  Year  \
# 0                 NaN        Uninsured         NaN      NaN       NaN  2025
# 1            Check BP              NaN         NaN      NaN       NaN  2025
# 2                 NaN              NaN         NaN      NaN       NaN  2025
# 3                 NaN          Insured  Hospital B    120.0      80.0  2025
# 4  Follow-up required              NaN         NaN    200.0     150.0  2025
#
#    Month  Day  Weekday
# 0      2   20        3
# 1      2   20        3
# 2      1   10        4
# 3      2   20        3
# 4      1   10        4
#
# [5 rows x 23 columns]

# %%
df['Doctor_Notes']=data['Doctor_Notes']

# %%
df['Doctor_Notes'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 200 entries, 0 to 199
# Series name: Doctor_Notes
# Non-Null Count  Dtype
# --------------  -----
# 102 non-null    object
# dtypes: object(1)
# memory usage: 1.7+ KB

# %%
df['Doctor_Notes'].value_counts()
# Out:
# Doctor_Notes
# Check BP              56
# Follow-up required    46
# Name: count, dtype: int64

# %%
null_indices = df[df['Doctor_Notes'].isna()].index
n_nulls = len(null_indices)
p_check = 56 / (56 + 46)
p_follow = 46 / (56 + 46)
n_check = int(p_check * n_nulls)
n_follow = n_nulls - n_check
fill_values = ['Check BP'] * n_check + ['Follow-up required'] * n_follow
np.random.shuffle(fill_values)
df.loc[null_indices, 'Doctor_Notes'] = fill_values

# %%
df['Doctor_Notes'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 200 entries, 0 to 199
# Series name: Doctor_Notes
# Non-Null Count  Dtype
# --------------  -----
# 200 non-null    object
# dtypes: object(1)
# memory usage: 1.7+ KB

# %%
df.drop('Insurance_Status',axis=1,inplace=True)

# %%
df.drop('Visit_Date',axis=1,inplace=True)

# %%
df['Hospital'].fillna(df['Hospital'].mode()[0], inplace=True)
# Out:
# <ipython-input-67-d869fe8f42d5>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Hospital'].fillna(df['Hospital'].mode()[0], inplace=True)

# %%
df['Hospital'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 200 entries, 0 to 199
# Series name: Hospital
# Non-Null Count  Dtype
# --------------  -----
# 200 non-null    object
# dtypes: object(1)
# memory usage: 1.7+ KB

# %%
df['Alcohol_Intake'].value_counts()
# Out:
# Alcohol_Intake
# Moderate    42
# High        38
# Name: count, dtype: int64

# %%
df.drop('Alcohol_Intake',axis=1,inplace=True)

# %%
df['Systolic'].fillna(df['Systolic'].mean(), inplace=True)
df['Diastolic'].fillna(df['Diastolic'].mean(), inplace=True)
# Out:
# <ipython-input-71-f988c1a59dbb>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Systolic'].fillna(df['Systolic'].mean(), inplace=True)
# <ipython-input-71-f988c1a59dbb>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Diastolic'].fillna(df['Diastolic'].mean(), inplace=True)

# %%
df.head()
# Out:
#      Age  Gender   Height_cm  Weight_kg    BMI  Heart_Rate Cholesterol  \
# 0   25.0    Male  160.000000       70.0  100.0        72.0      Normal
# 1   40.0    Male  175.000000       80.0   22.0       -20.0        High
# 2  102.0  Female  244.141104      -45.0   27.5       -20.0      Normal
# 3  150.0  Female  180.000000       80.0  100.0       100.0      normal
# 4   40.0    Male  999.000000       90.0  100.0        -3.0      normal
#
#   Diabetes Exercise_Freq Medication     Diagnosis  Follow_Up_Days  \
# 0        Y        Weekly      DrugB  Hypertension       41.052632
# 1        Y         Never      DrugA      Diabetes       60.000000
# 2        Y         Daily      DrugB      Diabetes       41.052632
# 3       No        Weekly      DrugA  Hypertension       30.000000
# 4       No        Weekly    Unknown  Hypertension       90.000000
#
#          Doctor_Notes    Hospital    Systolic   Diastolic  Year  Month  Day  \
# 0            Check BP  Hospital A  157.235772  110.325203  2025      2   20
# 1            Check BP  Hospital A  157.235772  110.325203  2025      2   20
# 2            Check BP  Hospital A  157.235772  110.325203  2025      1   10
# 3  Follow-up required  Hospital B  120.000000   80.000000  2025      2   20
# 4  Follow-up required  Hospital A  200.000000  150.000000  2025      1   10
#
#    Weekday
# 0        3
# 1        3
# 2        4
# 3        3
# 4        4

# %%
df.isnull().sum()
# Out:
# Age               0
# Gender            0
# Height_cm         0
# Weight_kg         0
# BMI               0
# Heart_Rate        0
# Cholesterol       0
# Diabetes          0
# Exercise_Freq     0
# Medication        0
# Diagnosis         0
# Follow_Up_Days    0
# Doctor_Notes      0
# Hospital          0
# Systolic          0
# Diastolic         0
# Year              0
# Month             0
# Day               0
# Weekday           0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
numerical_features = df.select_dtypes(include=np.number).columns

for feature in numerical_features:
  plt.figure(figsize=(8, 6))
  plt.boxplot(df[feature].dropna())
  plt.title(f"Box Plot of {feature}")
  plt.ylabel(feature)
  plt.show()

# %%
df = df[df['Height_cm'] != df['Height_cm'].min()]
df = df[df['Height_cm'] != df['Height_cm'].max()]

# %%
df = df[df['Weight_kg'] != df['Weight_kg'].min()]

# %%
df = df[df['BMI'] != df['BMI'].max()]

# %%
df = df[df['Systolic'] != df['Systolic'].max()]

# %%
df = df[df['Diastolic'] != df['Diastolic'].max()]

# %%
numerical_features = df.select_dtypes(include=np.number).columns

for feature in numerical_features:
  plt.figure(figsize=(8, 6))
  plt.boxplot(df[feature].dropna())
  plt.title(f"Box Plot of {feature}")
  plt.ylabel(feature)
  plt.show()

# %%
df.head()
# Out:
#            Age   Gender  Height_cm  Weight_kg   BMI  Heart_Rate Cholesterol  \
# 11   25.000000   Female      175.0  60.000000  -3.0       -20.0      Normal
# 19   40.000000   Female      180.0  60.000000  -3.0        85.0         Low
# 21   40.000000  Unknown      175.0  80.000000  -3.0       100.0        high
# 44   58.231214     Male      175.0  60.000000  -3.0       200.0        High
# 52  150.000000     Male      180.0  51.715976  22.0        -3.0      Normal
#
#    Diabetes Exercise_Freq Medication     Diagnosis  Follow_Up_Days  \
# 11       No        Rarely      DrugB      Diabetes      -10.000000
# 19  Unknown         Never      DrugA      Diabetes       41.052632
# 21      Yes         Never    Unknown  Hypertension       30.000000
# 44  Unknown        Weekly    Unknown  Hypertension       90.000000
# 52       No       invalid      DrugB  Hypertension       41.052632
#
#           Doctor_Notes    Hospital  Systolic  Diastolic  Year  Month  Day  \
# 11            Check BP  Hospital B     120.0       80.0  2025      1   10
# 19  Follow-up required  Hospital B     140.0       90.0  2025      1   10
# 21  Follow-up required  Hospital A     120.0       80.0  2025      1   10
# 44  Follow-up required  Hospital B     140.0       90.0  2025      2   20
# 52            Check BP  Hospital A     140.0       90.0  2025      1   10
#
#     Weekday
# 11        4
# 19        4
# 21        4
# 44        3
# 52        4

# %%
dummies = pd.get_dummies(df['Gender'])
df= pd.concat([df, dummies], axis=1)

# %%
df.drop('Gender',axis=1,inplace=True)

# %%
df['Cholesterol_encoded'], uniques = pd.factorize(df['Cholesterol'])

# %%
for col in ['Cholesterol', 'Diabetes', 'Exercise_Freq', 'Medication', 'Diagnosis']:
    df[col + '_encoded'], _ = pd.factorize(df[col])

# %%
df.head()
# Out:
#            Age  Height_cm  Weight_kg   BMI  Heart_Rate Cholesterol Diabetes  \
# 11   25.000000      175.0  60.000000  -3.0       -20.0      Normal       No
# 19   40.000000      180.0  60.000000  -3.0        85.0         Low  Unknown
# 21   40.000000      175.0  80.000000  -3.0       100.0        high      Yes
# 44   58.231214      175.0  60.000000  -3.0       200.0        High  Unknown
# 52  150.000000      180.0  51.715976  22.0        -3.0      Normal       No
#
#    Exercise_Freq Medication     Diagnosis  ...  Day Weekday Female   Male  \
# 11        Rarely      DrugB      Diabetes  ...   10       4   True  False
# 19         Never      DrugA      Diabetes  ...   10       4   True  False
# 21         Never    Unknown  Hypertension  ...   10       4  False  False
# 44        Weekly    Unknown  Hypertension  ...   20       3  False   True
# 52       invalid      DrugB  Hypertension  ...   10       4  False   True
#
#     Unknown  Cholesterol_encoded  Diabetes_encoded  Exercise_Freq_encoded  \
# 11    False                    0                 0                      0
# 19    False                    1                 1                      1
# 21     True                    2                 2                      1
# 44    False                    3                 1                      2
# 52    False                    0                 0                      3
#
#     Medication_encoded  Diagnosis_encoded
# 11                   0                  0
# 19                   1                  0
# 21                   2                  1
# 44                   2                  1
# 52                   0                  1
#
# [5 rows x 27 columns]

# %%
df.drop('Diagnosis',axis=1,inplace=True)
df.drop('Medication',axis=1,inplace=True)
df.drop('Exercise_Freq',axis=1,inplace=True)
df.drop('Cholesterol',axis=1,inplace=True)
df.drop('Diabetes',axis=1,inplace=True)

# %%
for col in ['Doctor_Notes' ,	'Hospital']:
    df[col + '_encoded'], _ = pd.factorize(df[col])

# %%
df.drop('Doctor_Notes',axis=1,inplace=True)
df.drop('Hospital',axis=1,inplace=True)

# %%
df.head()
# Out:
#            Age  Height_cm  Weight_kg   BMI  Heart_Rate  Follow_Up_Days  \
# 11   25.000000      175.0  60.000000  -3.0       -20.0      -10.000000
# 19   40.000000      180.0  60.000000  -3.0        85.0       41.052632
# 21   40.000000      175.0  80.000000  -3.0       100.0       30.000000
# 44   58.231214      175.0  60.000000  -3.0       200.0       90.000000
# 52  150.000000      180.0  51.715976  22.0        -3.0       41.052632
#
#     Systolic  Diastolic  Year  Month  ...  Female   Male  Unknown  \
# 11     120.0       80.0  2025      1  ...    True  False    False
# 19     140.0       90.0  2025      1  ...    True  False    False
# 21     120.0       80.0  2025      1  ...   False  False     True
# 44     140.0       90.0  2025      2  ...   False   True    False
# 52     140.0       90.0  2025      1  ...   False   True    False
#
#     Cholesterol_encoded  Diabetes_encoded  Exercise_Freq_encoded  \
# 11                    0                 0                      0
# 19                    1                 1                      1
# 21                    2                 2                      1
# 44                    3                 1                      2
# 52                    0                 0                      3
#
#     Medication_encoded  Diagnosis_encoded  Doctor_Notes_encoded  \
# 11                   0                  0                     0
# 19                   1                  0                     1
# 21                   2                  1                     1
# 44                   2                  1                     1
# 52                   0                  1                     0
#
#     Hospital_encoded
# 11                 0
# 19                 0
# 21                 1
# 44                 0
# 52                 1
#
# [5 rows x 22 columns]
